# %%
from tqdm import tqdm_notebook
from transformers import pipeline
import pandas as pd
import torch
from tqdm.notebook import tqdm

tqdm.pandas()

# %%
model_path = "./model/classification/cosine-bleu-C1-Tmean"
model = pipeline(
    "text-classification",
    model=model_path,
    truncation=True,
    device=0 if torch.cuda.is_available() else -1,
)

# %%
data_dir = model_path.split("/")[-1].replace("-", "_").split("_T")[0] + "_.csv"
data = pd.read_csv("./evaluation/speed/" + data_dir)

# %%
def get_threshold(df, th_type):
    if th_type == "mean":
        return df["max_score"].mean()
    elif th_type == "0.65":
        return 0.65
    elif th_type == "%75":
        return df["max_score"].quantile(0.75)

# %%
threshold = model_path.split("-")[-1].removeprefix("T")
data["max_score"] = data.apply(lambda x: x[x["fastest"]], axis=1)
filtered = data[data["max_score"] >= get_threshold(data, threshold)]

# %%
test_data = data[~data.index.isin(filtered.index)]

# %%
test_data
# Out:
#                                                      code  \
# 2       protected AuditMessageType getPatientParticipa...
# 3       public synchronized void registerListener(Drui...
# 4       public Step loadVariantsStep(StepBuilderFactor...
# 5       public int hashCode() { int result = factType....
# 7       public boolean visit(TypeDeclaration elem) { U...
# ...                                                   ...
# 150670  public Config(Map<String, String> properties) ...
# 150671  public CacheImpl(String name) { this.name = na...
# 150672  public void sendResponse(ReplyHeader h, Record...
# 150673  public void execute(IProgressMonitor m) throws...
# 150674  Slf4j(final Class<?> clazz) { this(clazz, Slf4...
#
#                                                   comment    bert     bow  \
# 2       Since we're using an enhanced for loop, does c...  0.0889  0.0235
# 3       I think it might be better to add to the list ...  0.0802  0.0498
# 4       can we remove this then? I think the main reas...  0.1291  0.1282
# 5       I'm still scared something stupid not using re...  0.0172  0.0206
# 7                           Is this needed for externals?  0.0269  0.0130
# ...                                                   ...     ...     ...
# 150670  one more method where it can take file locatio...  0.0343  0.0343
# 150671  I would prefer to initialize these inline in f...  0.1179  0.1254
# 150672  This IOException is swallowed either, should w...  0.0810  0.0161
# 150673  1) When would getCause return null? 2) Why dro...  0.1098  0.1181
# 150674  it's better to do this(clazz.getName()) here a...  0.0940  0.1384
#
#         doc2vec   tfidf  word2vec               max   fastest  max_score
# 2        0.0235  0.0235    0.0235              bert      bert     0.0889
# 3        0.0802  0.0498    0.0454      bert,doc2vec   doc2vec     0.0802
# 4        0.1291  0.1282    0.1282      bert,doc2vec   doc2vec     0.1291
# 5        0.0219  0.1192    0.0206             tfidf     tfidf     0.1192
# 7        0.0013  0.0415    0.0004             tfidf     tfidf     0.0415
# ...         ...     ...       ...               ...       ...        ...
# 150670   0.0413  0.0343    0.0343           doc2vec   doc2vec     0.0413
# 150671   0.0577  0.0867    0.0577               bow       bow     0.1254
# 150672   0.0766  0.0162    0.0180              bert      bert     0.0810
# 150673   0.1181  0.0291    0.0206       bow,doc2vec   doc2vec     0.1181
# 150674   0.1582  0.0871    0.1582  doc2vec,word2vec  word2vec     0.1582
#
# [94699 rows x 10 columns]

# %%
test_data["predicted"] = test_data["code"].progress_apply(
    lambda x: model(x)[0]["label"]
)
test_data["predicted_score"] = test_data.apply(lambda x: x[x["predicted"]], axis=1)

# %%
test_data.to_csv("predicted.csv")

# %%
res = pd.read_csv("predicted.csv", index_col=0)

# %%
res
# Out:
#                                                      code  \
# 2       protected AuditMessageType getPatientParticipa...
# 3       public synchronized void registerListener(Drui...
# 4       public Step loadVariantsStep(StepBuilderFactor...
# 5       public int hashCode() { int result = factType....
# 7       public boolean visit(TypeDeclaration elem) { U...
# ...                                                   ...
# 150670  public Config(Map<String, String> properties) ...
# 150671  public CacheImpl(String name) { this.name = na...
# 150672  public void sendResponse(ReplyHeader h, Record...
# 150673  public void execute(IProgressMonitor m) throws...
# 150674  Slf4j(final Class<?> clazz) { this(clazz, Slf4...
#
#                                                   comment    bert     bow  \
# 2       Since we're using an enhanced for loop, does c...  0.0889  0.0235
# 3       I think it might be better to add to the list ...  0.0802  0.0498
# 4       can we remove this then? I think the main reas...  0.1291  0.1282
# 5       I'm still scared something stupid not using re...  0.0172  0.0206
# 7                           Is this needed for externals?  0.0269  0.0130
# ...                                                   ...     ...     ...
# 150670  one more method where it can take file locatio...  0.0343  0.0343
# 150671  I would prefer to initialize these inline in f...  0.1179  0.1254
# 150672  This IOException is swallowed either, should w...  0.0810  0.0161
# 150673  1) When would getCause return null? 2) Why dro...  0.1098  0.1181
# 150674  it's better to do this(clazz.getName()) here a...  0.0940  0.1384
#
#         doc2vec   tfidf  word2vec               max   fastest  max_score  \
# 2        0.0235  0.0235    0.0235              bert      bert     0.0889
# 3        0.0802  0.0498    0.0454      bert,doc2vec   doc2vec     0.0802
# 4        0.1291  0.1282    0.1282      bert,doc2vec   doc2vec     0.1291
# 5        0.0219  0.1192    0.0206             tfidf     tfidf     0.1192
# 7        0.0013  0.0415    0.0004             tfidf     tfidf     0.0415
# ...         ...     ...       ...               ...       ...        ...
# 150670   0.0413  0.0343    0.0343           doc2vec   doc2vec     0.0413
# 150671   0.0577  0.0867    0.0577               bow       bow     0.1254
# 150672   0.0766  0.0162    0.0180              bert      bert     0.0810
# 150673   0.1181  0.0291    0.0206       bow,doc2vec   doc2vec     0.1181
# 150674   0.1582  0.0871    0.1582  doc2vec,word2vec  word2vec     0.1582
#
#        predicted  predicted_score
# 2       word2vec           0.0235
# 3       word2vec           0.0454
# 4       word2vec           0.1282
# 5           bert           0.0172
# 7       word2vec           0.0004
# ...          ...              ...
# 150670     tfidf           0.0343
# 150671       bow           0.1254
# 150672  word2vec           0.0180
# 150673  word2vec           0.0206
# 150674     tfidf           0.0871
#
# [94699 rows x 12 columns]

# %%
test_data.mean(numeric_only=True)
# Out:
# bert               0.060059
# bow                0.058744
# doc2vec            0.058614
# tfidf              0.058947
# word2vec           0.058431
# max_score          0.098434
# predicted_score    0.065411
# dtype: float64
